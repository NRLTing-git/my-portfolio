# %%
import requests
import pandas as pd
import numpy as np
import json
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from bs4 import BeautifulSoup
import re
import time

# %% [markdown]
# # Billboard Dataset

# %%
def topartists(year):
    """Retrieve the top artists for a specific year according to Billboard
    charts.

    This function sends a GET request to the Billboard website to fetch the top
    artists for the specified year.
    It then extracts and returns the list of top artists in a pandas DataFrame.

    Parameters
    ----------
    year : int
        The year for which you want to retrieve the top artists.

    Returns
    -------
    pandas.DataFrame
        A DataFrame containing the top artists for the specified year.
    """
    
    response = requests.get(
        f'https://www.billboard.com/charts/year-end/{year}/top-artists/'
    )
    soup = BeautifulSoup(response.text)
    artists = [
        {'Artist': artist.select_one('li > h3').text.strip()}
        for artist in soup.select('div.o-chart-results-list-row-container')
    ]
    df_artists = pd.DataFrame(artists)
    df_artists.index = np.arange(1, len(df_artists) + 1)

    return df_artists

def alltopartists():
    """Retrieve the top artists for multiple years from 2006 to 2022 according
    to Billboard charts.

    This function iterates through the years from 2006 to 2022 and retrieves
    the top artists for each year by calling the `topartists` function.
    It then combines the data for all years into a single pandas DataFrame
    and removes duplicates.

    Returns
    -------
    pandas.DataFrame
        A DataFrame containing the top artists from 2006 to 2022 without
        duplicates.
    """
    df_all = pd.DataFrame()
    for i in range(2006,2023):
        df_all = pd.concat([df_all,topartists(i)])
    df_all = df_all.drop_duplicates(keep='first', inplace=False,
                                    ignore_index=True)
    df_all.index = np.arange(1, len(df_all) + 1)

    return df_all

# %% [markdown]
# Note: Result may not be the same due to changes in Billboard website. Refer to artists.pkl to read original scraped artists used.

# %%
artists_df = alltopartists()
artists_df
# Out:
#                Artist
# 1         Chris Brown
# 2          Nickelback
# 3       Rascal Flatts
# 4           Sean Paul
# 5               Ne-Yo
# ..                ...
# 502      Brent Faiyaz
# 503    Jessica Darrow
# 504  Chencho Corleone
# 505              CKay
# 506           Nirvana
#
# [506 rows x 1 columns]

# %% [markdown]
# # Wikipedia Dataset

# %% [markdown]
# We'll use the original artists dataset here that was scraped Nov. 16, 2023.

# %%
artists_df_old = pd.read_pickle('artists.pkl')
artists_df_old
# Out:
#                     Name
# 0               2 Chainz
# 1              21 Savage
# 2               24kGoldn
# 3                  3OH!3
# 4    5 Seconds Of Summer
# ..                   ...
# 500            blackbear
# 501                 fun.
# 502                gnash
# 503    twenty one pilots
# 504            will.i.am
#
# [505 rows x 1 columns]

# %%
def scrape_wikipedia_sidebar(url,
                             keywords=["band", "musician", "singer",
                                       "rapper", "artist"]
                            ):
    """Scrape information from the sidebar of a Wikipedia page or find relevant
    links.

    This function makes an HTTP request to a Wikipedia page specified by the
    provided URL. It attempts to scrape information from the sidebar of the
    page and returns a dictionary containing the extracted data. If the page is
    a disambiguation page or does not have a sidebar, the function searches
    for relevant links in the notable people
    section or the page itself, following the provided keywords.

    Parameters
    ----------
    url : str
        The URL of the Wikipedia page to scrape.
    keywords : list of str, optional
        Keywords used to identify relevant links when searching for people.
        Default is ["band", "musician", "singer", "rapper", "artist"].

    Returns
    -------
    dict or None
        If a sidebar is found on the Wikipedia page, a dictionary containing
        the extracted data is returned. If no relevant information is found
        or if the request is unsuccessful, None is returned.
    """
    # Make an HTTP request to the Wikipedia page
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, "html.parser")

        # Find the sidebar element (class="infobox")
        sidebar = soup.find("table", {"class": "infobox"})

        if sidebar:
            print("Sidebar found. Extracting information...")

            # Create a dictionary to store the information
            sidebar_data = {}

            # Iterate through rows in the sidebar table
            for row in sidebar.find_all("tr"):
                # Find the header and data cells
                header_cell = row.find("th")
                data_cell = row.find("td")

                # Check if both header and data cells exist
                if header_cell and data_cell:
                    # Extract text from header and data cells
                    header = header_cell.get_text(strip=True)
                    data = " ".join(data_cell.stripped_strings)

                    # Add the information to the dictionary
                    sidebar_data[header] = data

            return sidebar_data
        else:
            # Check if there is a section with a list of people
            people_section = soup.find("div", {"id": "setindexbox"})

            if people_section:
                print("Notable people section found. Finding relevant link...")

                # Find the first link containing keywords
                for link in soup.find_all("a", href=True):
                    if any(keyword in link.text.lower()
                           for keyword in keywords):
                        new_url = "https://en.wikipedia.org" + link["href"]
                        print(f"Found relevant link: {new_url}")
                        return scrape_wikipedia_sidebar(new_url)

                print("No relevant link found in the notable people section.")
                print(url)
                return None
            elif soup.find("div", {"id": "disambigbox"}):
                print("Disambiguation page detected. Finding relevant link...")

                # Find the first link containing keywords
                for link in soup.find_all("a", href=True):
                    if any(keyword in link.text.lower()
                           for keyword in keywords):
                        new_url = "https://en.wikipedia.org" + link["href"]
                        print(f"Found relevant link: {new_url}")
                        return scrape_wikipedia_sidebar(new_url)

                print("No relevant link found in the disambiguation page.")
                print(url)
                return None
            else:
                print(
                    """The page does not seem to be a disambiguation page
                    or have a sidebar or notable people section."""
                )
                print(url)
                return None
    else:
        # Print an error message if the request was not successful
        print(
            "Error: Unable to retrieve the Wikipedia page (Status code "
            f"{response.status_code})"
        )
        print(url)


def get_wikipedia_url(title):
    """
    Retrieve the URL of a Wikipedia page by its title.

    This function queries the Wikipedia API to obtain the URL of a Wikipedia
    page based on its title.

    Parameters
    ----------
    title : str
        The title of the Wikipedia page for which the URL is to be retrieved.
    """
    api_url = "https://en.wikipedia.org/w/api.php"

    # Define parameters for the API request to get page information
    params = {
        "action": "query",
        "format": "json",
        "titles": title,
        "prop": "info",
        "inprop": "url",
    }

    # Make the API request
    response = requests.get(api_url, params=params)
    data = response.json()

    # Extract information from the API response
    page_id = list(data["query"]["pages"].keys())[0]

    # Check if the page exists
    if page_id != "-1":
        # Get the URL of the page
        page_url = data["query"]["pages"][page_id]["fullurl"]
        return page_url
    else:
        return f"Page with title '{title}' not found."

# %%
names = artists_df_old['Name'].to_list()
urls = []
for name in names:
    url = get_wikipedia_url(name)
    urls.append(url)
    time.sleep(.5)
len(urls)
# Out:
# 505

# %%
for i in range(len(urls)):
    if urls[i] == "https://en.wikipedia.org/wiki/Bastille":
        urls[i] = "https://en.wikipedia.org/wiki/Bastille_(disambiguation)"
    elif urls[i] == "https://en.wikipedia.org/wiki/Eagles":
        urls[i] = "https://en.wikipedia.org/wiki/Eagles_(disambiguation)"
    elif urls[i] == "https://en.wikipedia.org/wiki/CJ":
        urls[i] = "https://en.wikipedia.org/wiki/CJ_(rapper)"
    elif urls[i] == 'https://en.wikipedia.org/wiki/Cassie':
        urls[i] = 'https://en.wikipedia.org/wiki/Cassie_Ventura'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Future':
        urls[i] = 'https://en.wikipedia.org/wiki/Future_(rapper)'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Muse':
        urls[i] = 'https://en.wikipedia.org/wiki/Muse_(band)'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Mustard':
        urls[i] = 'https://en.wikipedia.org/wiki/Mustard_(record_producer)'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Logic':
        urls[i] = 'https://en.wikipedia.org/wiki/Logic_(rapper)'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Nirvana':
        urls[i] = 'https://en.wikipedia.org/wiki/Nirvana_(band)'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Passenger':
        urls[i] = 'https://en.wikipedia.org/wiki/Passenger_(singer)'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Prince':
        urls[i] = 'https://en.wikipedia.org/wiki/Prince_(musician)'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Train':
        urls[i] = 'https://en.wikipedia.org/wiki/Train_(band)'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Zayn':
        urls[i] = 'https://en.wikipedia.org/wiki/Zayn_Malik'
    elif urls[i] == 'https://en.wikipedia.org/wiki/Pitbull':
        urls[i] = 'https://en.wikipedia.org/wiki/Pitbull_(rapper)'
    elif urls[i] ==  'https://en.wikipedia.org/wiki/Bow_Wow':
        urls[i] = 'https://en.wikipedia.org/wiki/Bow_Wow_(rapper)'

# %%
scraped_sidebars = []
sidebars_content = []
for url in urls:
    sidebar = scrape_wikipedia_sidebar(url)
    scraped_sidebars.append(sidebar)
    sidebars_content.append([' '.join(list(sidebar.values()))])
    print(sidebar)
    time.sleep(.5)
# Out:
# Sidebar found. Extracting information...
# {'Born': 'Tauheed K. Epps ( 1977-09-12 ) September 12, 1977 (age\xa046) College Park, Georgia , U.S.', 'Other\xa0names': 'Tity Boi Drenchgod', 'Alma\xa0mater': 'Virginia State University ( BS )', 'Occupations': 'Rapper songwriter', 'Years\xa0active': '1997–present', 'Spouse': 'Kesha Ward \u200b ( m. 2018) \u200b', 'Children': '3', 'Awards': 'Full list', 'Genres': 'Hip hop dirty south trap [1]', 'Instrument(s)': 'Vocals', 'Labels': 'Gamebread T.R.U. Def Jam [2]', 'Formerly of': 'Playaz Circle DTP', 'Website': '2chainz .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Shéyaa Bin Abraham-Joseph', 'Born': '( 1992-10-22 ) October 22, 1992 (age\xa031) Plaistow , London , England', 'Origin': 'Atlanta, Georgia , U.S.', 'Genres': 'Hip hop trap horrorcore', 'Occupation(s)': 'Rapper songwriter record producer', 'Years active': '2013–present', 'Labels': 'Epic The Orchard Slaughter Gang', 'Children': '3', 'Website': 'shop .21savage .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Golden Landis Von Jones', 'Also known as': 'Goldn El Dorado', 'Born': '( 2000-11-13 ) November 13, 2000 (age\xa023) San Francisco, California , U.S.', 'Genres': 'Pop rap [1] hip hop emo rap', 'Occupation(s)': 'Rapper singer songwriter', 'Years active': '2016–present', 'Labels': 'RECORDS Columbia', 'Website': '24kgoldn .com'}
# Sidebar found. Extracting information...
# {'Origin': 'Boulder, Colorado , U.S.', 'Genres': 'Electropop synth-pop dance-pop pop rap crunkcore trap', 'Years active': '2004–present', 'Labels': 'Fueled by Ramen Photo Finish Atlantic', 'Members': 'Sean Foreman Nathaniel Motte', 'Website': '3oh3 .com'}
# Sidebar found. Extracting information...
# {'Also known as': '5SOS', 'Origin': 'Sydney , New South Wales , Australia', 'Genres': 'Pop rock pop pop punk power pop new wave', 'Years active': '2011–present', 'Labels': 'BMG Capitol Hi or Hey Interscope [1]', 'Members': 'Luke Hemmings Calum Hood Ashton Irwin Michael Clifford', 'Website': '5sos .com'}
# Sidebar found. Extracting information...
# {'Born': 'Curtis James Jackson III ( 1975-07-06 ) July 6, 1975 (age\xa048) New York City , U.S.', 'Occupations': 'Rapper songwriter actor television producer record producer record executive businessman', 'Years\xa0active': '1996 ( 1996 ) –present [1]', 'Organization': 'G-Unity Foundation', 'Works': 'Albums singles group records clothing books multimedia videography', 'Television': '50 Central 50 Cent: The Money and the Power For Life Power The Oath [2]', 'Children': '2', 'Awards': 'Full list', 'Genres': 'Hip hop', 'Labels': 'Caroline Capitol G-Unit Shady Aftermath Interscope Universal Columbia Trackmasters JMJ', 'Formerly of': 'G-Unit', 'Website': '50cent .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Daniel Hernandez', 'Also known as': 'Tekashi69 [1] Tekashi 6ix9ine [2] Wallah Dan [3]', 'Born': '( 1996-05-08 ) May 8, 1996 (age\xa027) New York City , U.S.', 'Genres': 'Hip hop scream rap hardcore hip hop SoundCloud rap punk rap', 'Occupation(s)': 'Rapper songwriter', 'Years active': '2012–2018 2020–present', 'Labels': 'Giné [4] Create 10K Projects Virgin Scumgang Tr3yway', 'Children': '2 [5]', 'Website': '6ix9inestore .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Artist Julius Dubose', 'Born': '( 1995-12-06 ) December 6, 1995 (age\xa027) New York City , U.S.', 'Genres': 'Hip hop trap R&B', 'Occupation(s)': 'Rapper singer songwriter actor', 'Years active': '2015–present', 'Labels': 'Highbridge The Label Atlantic', 'Children': '2', 'Website': 'aboogiehbtl .com'}
# Sidebar found. Extracting information...
# {'Origin': 'New York City , New York , United States', 'Genres': 'Pop rock pop', 'Years active': '2011–present', 'Labels': 'Epic', 'Members': 'Ian Axel Chad King (born Vaccarino)', 'Website': 'agreatbigworld .com'}
# Sidebar found. Extracting information...
# {'Born': 'Rakim Athelaston Mayers ( 1988-10-03 ) October 3, 1988 (age\xa035) New York City , U.S.', 'Other\xa0names': 'Lord Flacko Pretty Flacko Jodye II', 'Education': 'Bayard Rustin Educational Complex', 'Occupations': 'Rapper singer-songwriter record producer', 'Years\xa0active': '2007–present', 'Agent': 'William Morris Endeavor', 'Works': 'Discography production', 'Partner': 'Rihanna (2020–present) [1]', 'Children': '2', 'Awards': 'Full list', 'Genres': 'Hip hop trap psychedelic rap experimental hip hop cloud rap (early)', 'Labels': 'ASAP Worldwide AWGE Polo Grounds RCA', 'Member of': 'ASAP Mob', 'Website': 'asaprocky.com'}
# Sidebar found. Extracting information...
# {'Origin': 'Sydney, New South Wales, Australia', 'Genres': 'Hard rock blues-rock rock and roll heavy metal', 'Discography': 'Albums and singles songs', 'Years active': '1973–present (On hiatus: 2016–2018)', 'Labels': 'Albert Atlantic ATCO East West Elektra Epic Columbia', 'Spinoff of': 'Marcus Hook Roll Band', 'Members': 'Angus Young Phil Rudd Cliff Williams Brian Johnson Stevie Young', 'Website': 'acdc .com'}
# Disambiguation page detected. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/AJR_(band)
# Sidebar found. Extracting information...
# {'Origin': 'New York City , U.S.', 'Genres': 'Indie pop alternative electropop electronic', 'Discography': 'AJR discography', 'Years active': '2005–present', 'Labels': 'AJR Productions Warner BMG Mercury Republic', 'Members': 'Adam Met [1] Jack Met Ryan Met', 'Website': 'ajrbrothers .com'}
# Sidebar found. Extracting information...
# {'Origin': 'Los Angeles , California , U.S.', 'Genres': 'Alternative rock electronic rock indie rock electropop pop rock dance-rock', 'Discography': 'Awolnation discography', 'Years active': '2009–present', 'Labels': 'Better Noise Red Bull', 'Spinoff of': 'Under the Influence of Giants Home Town Hero', 'Members': 'Aaron Bruno Isaac Carpenter Zach Irons Daniel Saslow Josh Moreau', 'Past members': 'Jimmy Messer Billy Mohler Dave Amezcua Christopher Thorn Devin Hoffman Hayden Scott [1] Drew Stewart Kenny Carkeet Marc Walloch Michael Goldman', 'Website': 'awolnationmusic .com'}
# Sidebar found. Extracting information...
# {'Born': 'Adam Mitchel Lambert ( 1982-01-29 ) January 29, 1982 (age\xa041) Indianapolis , Indiana, U.S.', 'Education': 'California State University, Fullerton (no degree)', 'Occupations': 'Singer songwriter actor', 'Years\xa0active': '2001–present', 'Origin': 'San Diego, California, U.S.', 'Genres': 'Pop [1] pop rock [1] dance [2] electronic [3]', 'Instrument(s)': 'Vocals', 'Labels': '19 RCA Warner Empire Warner Music Group / EastWest', 'Member of': 'Queen + Adam Lambert', 'Website': 'adamlambert .net'}
# Sidebar found. Extracting information...
# {'Born': 'Adele Laurie Blue Adkins ( 1988-05-05 ) 5 May 1988 (age\xa035) London , England', 'Alma\xa0mater': 'BRIT School for Performing Arts and Technology', 'Occupation': 'Singer-songwriter', 'Years\xa0active': '2006–present', 'Works': 'Discography songs recorded', 'Spouses': 'Simon Konecki \u200b \u200b ( m. 2018; div. 2021 ) \u200b Rich Paul \u200b ( m. 2023) \u200b', 'Children': '1', 'Awards': 'Full list', 'Genres': 'Pop [1] soul [2]', 'Instrument(s)': 'Vocals', 'Labels': 'XL Columbia Melted Stone', 'Website': 'adele .com'}
# Sidebar found. Extracting information...
# {'Born': 'Aliaune Damala Bouga Time Puru Nacka Lu Lu Lu Badara Akon Thiam [1] ( 1973-04-16 ) April 16, 1973 (age\xa050) St. Louis , Missouri , US', 'Other\xa0names': 'A-Kon El Negreeto', 'Citizenship': 'United States Senegal', 'Occupations': 'Singer songwriter rapper record producer entrepreneur philanthropist', 'Years\xa0active': '1996–present', 'Organization': 'Akon Lighting Africa', 'Agent': 'Johnny Wright', 'Works': 'Discography filmography production', 'Children': '9 [2]', 'Parent': 'Mor Thiam (father)', 'Awards': 'Full list', 'Origin': 'Newark, New Jersey , US', 'Genres': 'R&B hip hop pop', 'Labels': 'Akonik BMG Atlantic Konvict KonLive Republic Universal Motown SRC UpFront', 'Website': 'akon .com'}
# Sidebar found. Extracting information...
# {'Born': 'Alessia Caracciolo ( 1996-07-11 ) July 11, 1996 (age\xa027) [1] Mississauga , Ontario , Canada', 'Other\xa0names': 'Alessia (2014–2015)', 'Citizenship': 'Canada Italy [2]', 'Occupations': 'Singer songwriter', 'Years\xa0active': '2009–present', 'Genres': 'Pop R&B', 'Instrument(s)': 'Vocals', 'Labels': 'EP Def Jam [3] Universal Music Group [4]', 'Website': 'alessiacara .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Alexander George Clare [1] [2]', 'Born': '( 1985-09-14 ) September 14, 1985 (age\xa038) Southwark , London , England', 'Origin': 'Golders Green , London, England', 'Genres': 'Alternative rock electronica pop blue-eyed soul drum and bass R&B dubstep soul', 'Occupation(s)': 'Singer songwriter', 'Instrument(s)': 'Vocals guitars synthesizer drums keyboard ukulele sampler sequencer', 'Years active': '2007–present', 'Labels': 'Island Republic Universal Republic ETC Recordings'}
# Sidebar found. Extracting information...
# {'Born': 'Alicia Augello Cook ( 1981-01-25 ) January 25, 1981 (age\xa042) New York City , U.S.', 'Other\xa0names': 'Lellow', 'Occupations': 'Singer songwriter pianist author actress', 'Years\xa0active': '1994–present', 'Organization': 'Keep a Child Alive', 'Works': 'Discography songs written videography', 'Spouse': 'Swizz Beatz \u200b ( m. 2010) \u200b', 'Children': '2', 'Awards': 'Full list', 'Genres': 'R&B pop [1] soul hip hop [2]', 'Instrument(s)': 'Vocals piano', 'Labels': 'Columbia Arista J RCA AKW', 'Website': 'aliciakeys .com'}
# Sidebar found. Extracting information...
# {'Born': 'Egbert Nathaniel Dawkins III ( 1979-01-07 ) January 7, 1979 (age\xa044) Laguna Hills, California , U.S.', 'Occupations': 'Singer songwriter rapper', 'Years\xa0active': '1995–present', 'Spouse': 'Maya Jupiter \u200b ( m. 2010) \u200b', 'Children': '2', 'Genres': 'Hip hop soul R&B reggae pop', 'Instrument(s)': 'Vocals', 'Labels': 'Stones Throw Goontrax XIX Recordings Interscope Dirty Science Shaman Work', 'Formerly of': 'Emanon Quakers Roseaux', 'Website': 'www .aloeblacc .com'}
# Sidebar found. Extracting information...
# {'Also known as': 'The Blue Pages (2006–2012) [1]', 'Origin': 'Boston , Massachusetts, United States', 'Genres': 'Pop rock alternative rock folk rock indie rock', 'Years active': '2006–present', 'Labels': 'Mercury Island', 'Members': 'Zac Barnett Dave Rublin Matt Sanchez', 'Past members': 'James Adam Shelley', 'Website': 'weareamericanauthors .com'}
# Sidebar found. Extracting information...
# {'Born': 'Amy Jade Winehouse ( 1983-09-14 ) 14 September 1983 Southgate, London , England', 'Died': '23 July 2011 (2011-07-23) (aged\xa027) Camden Town , London, England', 'Cause\xa0of death': 'Alcohol poisoning', 'Resting place': 'Edgwarebury Cemetery, Edgware , London, England', 'Education': 'Sylvia Young Theatre School', 'Occupations': 'Singer songwriter', 'Years\xa0active': '2002–2011', 'Works': 'Discography songs recorded', 'Spouse': 'Blake Fielder-Civil \u200b \u200b ( m. 2007; div. 2009) \u200b', 'Partners': 'Alex Clare (2006–2007) Reg Traviss (2010–2011)', 'Awards': 'Full list', 'Genres': 'Soul blue-eyed soul neo soul rhythm and blues jazz', 'Labels': 'Island Lioness Universal Republic Republic', 'Website': 'amywinehouse .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Brandon Paak Anderson', 'Also known as': 'Breezy Lovejoy Cheeky Andy DJ Pee .Wee', 'Born': '( 1986-02-08 ) February 8, 1986 (age\xa037) Oxnard, California , U.S.', 'Education': 'Foothill Technology High School', 'Genres': 'R&B [1] hip hop soul funk pop [2]', 'Occupation(s)': 'Rapper singer songwriter record producer drummer', 'Instrument(s)': 'Vocals drums', 'Years active': '2007–present', 'Labels': 'Atlantic 12Tone Aftermath ArtClub SteelWool Stones Throw Empire Hellfyre Club OBE', 'Member of': 'NxWorries Silk Sonic', 'Spouse': 'Jaylyn \u200b ( m. 2011) \u200b', 'Children': '2', 'Website': 'www .andersonpaak .com'}
# Sidebar found. Extracting information...
# {'Born': '( 1958-09-22 ) 22 September 1958 (age\xa065) Lajatico , Italy', 'Genres': 'Opera operatic pop Latin pop classical traditional pop', 'Occupation(s)': 'Singer ( tenor )', 'Years active': '1992−present'}
# Sidebar found. Extracting information...
# {'Birth name': 'Andrew Charles Grammer', 'Born': '( 1983-12-03 ) December 3, 1983 (age\xa039) Los Angeles, California , U.S.', 'Genres': 'Pop rock soul pop country pop', 'Occupation(s)': 'Singer songwriter record producer', 'Instrument(s)': 'Vocals guitar piano trumpet', 'Years active': '2007–present', 'Labels': 'S-Curve , Mushroom Records', 'Spouse(s)': 'Aijia Grammer \u200b ( m. 2012) \u200b', 'Website': 'andygrammer .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Howard Andrew Williams', 'Born': '( 1927-12-03 ) December 3, 1927 Wall Lake, Iowa , U.S.', 'Died': 'September 25, 2012 (2012-09-25) (aged\xa084) Branson, Missouri , U.S.', 'Genres': 'Traditional pop , easy listening', 'Occupation(s)': 'Singer, actor', 'Years active': '1938–2012', 'Labels': 'Cadence Columbia London Polydor', 'Spouse(s)': 'Claudine Longet \u200b \u200b ( m. 1961; div. 1975) \u200b Debbie Haas \u200b ( m. 1991) \u200b', 'Website': 'andywilliams .com'}
# Sidebar found. Extracting information...
# {'Born': 'Anna Cooke Kendrick [1] ( 1985-08-09 ) August 9, 1985 (age\xa038) Portland, Maine , U.S.', 'Occupations': 'Actress singer', 'Years\xa0active': '1998–present', 'Awards': 'Full list'}
# Sidebar found. Extracting information...
# {'Also known as': 'Death Ramps', 'Origin': 'Sheffield , England', 'Genres': 'Indie rock garage rock post-punk revival psychedelic rock alternative rock lounge pop', 'Discography': 'Albums and singles songs', 'Years active': '2002–present', 'Labels': 'Domino Warner [1]', 'Spinoffs': 'The Last Shadow Puppets Mongrel', 'Members': "Alex Turner Matt Helders Jamie Cook Nick O'Malley", 'Past members': 'Andy Nicholson', 'Website': 'arcticmonkeys .com'}
# Sidebar found. Extracting information...
# {'Born': 'Ariana Grande-Butera ( 1993-06-26 ) June 26, 1993 (age\xa030) Boca Raton, Florida , U.S.', 'Occupations': 'Singer songwriter actress', 'Years\xa0active': '2008–present', 'Agent': 'Scooter Braun', 'Works': 'Discography songs recorded videography performances', 'Spouse': 'Dalton Gomez \u200b \u200b ( m. 2021; div. 2023) \u200b', 'Relatives': 'Frankie Grande (half-brother)', 'Awards': 'Full list', 'Genres': 'Pop R&B', 'Instruments': 'Vocals', 'Labels': 'Republic', 'Website': 'arianagrande .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Arizona Zervas', 'Born': '( 1995-04-19 ) April 19, 1995 (age\xa028) Providence, Rhode Island , U.S.', 'Origin': 'Hagerstown, Maryland , U.S.', 'Genres': 'Hip hop R&B trap', 'Occupation(s)': 'Rapper singer songwriter', 'Years active': '2016–present', 'Labels': 'Columbia', 'Website': 'arizonazervas .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Austin Harris Mahone', 'Born': '( 1996-04-04 ) April 4, 1996 (age\xa027) San Antonio, Texas , U.S.', 'Genres': 'Pop [1] R&B [2] dance-pop [3]', 'Occupation(s)': 'Singer songwriter', 'Instrument(s)': 'Vocals guitar piano', 'Years active': '2010–present', 'Labels': 'Universal Music Japan BMG Mr. 305 Inc. AM Music Cash Money Republic Chase', 'Website': 'austinmahone .com'}
# Sidebar found. Extracting information...
# {'Born': 'Amanda Koçi ( 1994-02-16 ) February 16, 1994 (age\xa029) Milwaukee, Wisconsin , U.S.', 'Other\xa0names': 'Amanda Kay AVA Ava Koci', 'Education': 'Lexington High School', 'Occupations': 'Singer songwriter', 'Years\xa0active': '2013–present', 'Notable work': 'Discography', 'Awards': 'Full list', 'Origin': 'Chesapeake, Virginia , U.S.', 'Genres': 'Pop dance-pop', 'Instruments': 'Vocals', 'Labels': 'Atlantic', 'Website': 'avamax .com'}
# Sidebar found. Extracting information...
# {'Born': 'Tim Bergling ( 1989-09-08 ) 8 September 1989 Stockholm , Sweden', 'Died': '20 April 2018 (2018-04-20) (aged\xa028) Muscat , Oman', 'Resting place': 'Hedvig Eleonora Church , Stockholm', 'Other\xa0names': 'Tim Berg Tom Hangs [1] Timberman', 'Occupations': 'DJ music producer remixer songwriter', 'Years\xa0active': '2006–2018', 'Parent': 'Anki Lidén (mother)', 'Relatives': 'Anton Körberg (half-brother) Birger Bergling (grandfather)', 'Awards': 'Full list', 'Genres': 'EDM progressive house electro house', 'Labels': 'Avicii Music AB Universal Music AB', 'Website': 'avicii .com'}
# Sidebar found. Extracting information...
# {'Born': 'Avril Ramona Lavigne ( 1984-09-27 ) September 27, 1984 (age\xa039) Belleville, Ontario , Canada', 'Citizenship': 'Canada France [1] [2]', 'Occupation': 'Singer-songwriter', 'Years\xa0active': '1999–present', 'Works': 'Discography songs concert tours promotional tours', 'Spouses': 'Deryck Whibley \u200b \u200b ( m. 2006; div. 2010) \u200b Chad Kroeger \u200b \u200b ( m. 2013; div. 2015) \u200b', 'Relatives': 'Ryota Kohama (brother-in-law)', 'Awards': 'Full list', 'Genres': 'Pop-punk alternative rock pop rock post-grunge', 'Instrument(s)': 'Vocals guitar piano drums', 'Labels': 'Arista RCA Epic BMG Avril Lavigne Music DTA Elektra', 'Website': 'avrillavigne .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Bobby Ray Simmons Jr.', 'Born': '( 1988-11-15 ) November 15, 1988 (age\xa035) Winston-Salem, North Carolina , U.S.', 'Origin': 'Decatur, Georgia , U.S.', 'Genres': 'Alternative hip hop dirty south pop rock [1]', 'Occupations': 'Rapper songwriter record producer', 'Discography': 'Recording production', 'Years active': '2006–present', 'Labels': 'No Genre Rebel Rock Grand Hustle Atlantic', 'Formerly of': 'All City Chess Club Hustle Gang', 'Website': 'shopbobbyray .com'}
# Sidebar found. Extracting information...
# {'Also known as': 'Bangtan Boys Bangtan Sonyeondan Beyond the Scene Bulletproof Boy Scouts', 'Origin': 'Seoul , South Korea', 'Genres': 'K-pop pop hip hop R&B EDM', 'Years active': '2013–present', 'Labels': 'Big Hit Pony Canyon Def Jam Japan [1] Columbia Universal Geffen', 'Members': 'Jin Suga J-Hope RM Jimin V Jungkook', 'Website': 'bts .ibighit .com', 'Hangul': '방탄 소년 단', 'Hanja': '防彈 少年 團', 'Transcriptions': 'Transcriptions Revised Hepburn Bōdan Shōnendan Kunrei-shiki Bôdan Syônendan', 'Revised Romanization': 'Bangtan Sonyeondan', 'McCune–Reischauer': "Pangt'an Sonyǒndan", 'Kanji': '防弾少年団', 'Hiragana': 'ぼうだんしょうねんだん', 'Revised Hepburn': 'Bōdan Shōnendan', 'Kunrei-shiki': 'Bôdan Syônendan'}
# Sidebar found. Extracting information...
# {'Birth name': 'Harry Bauer Rodrigues [1] [2]', 'Born': '( 1989-04-30 ) April 30, 1989 (age\xa034) Philadelphia , Pennsylvania , U.S.', 'Genres': 'EDM trap hip hop grime bass', 'Occupation(s)': 'Record producer, DJ', 'Years active': '2011–present', 'Labels': 'WeDidIt LuckyMe Jeffries', 'Website': 'baauer .com'}
# Sidebar found. Extracting information...
# {'Born': 'Hykeem Jamaal Carter Jr. ( 2000-10-22 ) October 22, 2000 (age\xa023) Carson, California , U.S.', 'Occupations': 'Rapper singer songwriter record producer', 'Years\xa0active': '2014–present', 'Relatives': 'Kendrick Lamar (cousin) Nick Young (cousin)', 'Also known as': '2 Phone Baby Keem Booman', 'Origin': 'Las Vegas , Nevada, U.S.', 'Genres': 'West Coast hip hop alternative hip hop trap', 'Labels': 'The Orchard PGLang Columbia', 'Website': 'keem .science'}
# Sidebar found. Extracting information...
# {'Origin': 'Orlando, Florida , U.S.', 'Genres': 'Pop dance-pop R&B teen pop [1] [2] adult contemporary', 'Years active': '1993–present', 'Labels': 'K-BAHN RCA Jive BMG Legacy', 'Members': 'AJ McLean Howie Dorough Nick Carter Kevin Richardson Brian Littrell', 'Website': 'backstreetboys .com'}
# Sidebar found. Extracting information...
# {'Born': 'Benito Antonio Martínez Ocasio ( 1994-03-10 ) March 10, 1994 (age\xa029) Vega Baja, Puerto Rico [1] [2] [3]', 'Occupations': 'Rapper singer songwriter record producer actor professional wrestler', 'Years\xa0active': '2013–present [4] [5]', 'Works': 'Discography', 'Awards': 'Full list', 'Genres': 'Latin trap reggaeton Latin pop Latin hip hop alternative reggaeton', 'Instrument(s)': 'Vocals', 'Labels': 'Hear This Music Rimas', 'Website': 'nadiesabeloquevaapasarmanana .com //'}
# Sidebar found. Extracting information...
# {'Origin': 'Detroit , Michigan , U.S.', 'Genres': 'Hip hop', 'Years active': '1998–2002 2010–present', 'Labels': 'Shady Interscope [1] Game', 'Members': 'Royce da 5\'9" (Bad) Eminem (Evil)', 'Website': 'badmeetsevil .net'}
# Sidebar found. Extracting information...
# {'Birth name': 'Bailey Lynn Zimmerman [1]', 'Born': '( 2000-01-27 ) January 27, 2000 (age\xa023) [2] Louisville, Illinois , U.S.', 'Genres': 'Country Southern rock', 'Occupation(s)': 'Singer songwriter', 'Instrument(s)': 'Vocals', 'Years active': '2020–present', 'Labels': 'Warner Nashville Elektra', 'Website': 'baileyzimmermanofficial .com'}
# Disambiguation page detected. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/Bastille_(band)
# Sidebar found. Extracting information...
# {'Origin': 'London, England', 'Genres': 'Indie pop pop rock synth-pop electropop alternative rock', 'Years active': '2010–present', 'Labels': 'Virgin EMI', 'Members': 'Dan Smith Kyle Simmons Will Farquarson Chris Wood', 'Website': 'bastillebastille .com'}
# Notable people section found. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/Bazzi_(singer)
# Sidebar found. Extracting information...
# {'Birth name': 'Andrew Bazzi', 'Born': '( 1997-08-28 ) August 28, 1997 (age\xa026) Canton, Michigan , U.S.', 'Genres': 'Pop [1] R&B [2]', 'Occupation(s)': 'Singer songwriter record producer', 'Instrument(s)': 'Vocals guitar piano', 'Years active': '2013–present', 'Labels': 'iamcosmic Atlantic [3] ZZZ', 'Website': 'bazziofficial .com'}
# Sidebar found. Extracting information...
# {'Born': 'Bleta Rexha ( 1989-08-30 ) August 30, 1989 (age\xa034) New York City , U.S.', 'Citizenship': 'United States North Macedonia [1]', 'Occupations': 'Singer songwriter', 'Years\xa0active': '2010–present', 'Works': 'Discography Songs', 'Awards': 'Full list', 'Genres': 'Pop [2] [3]', 'Instruments': 'Vocals', 'Labels': 'DCD2 First Access Island Def Jam Warner', 'Formerly of': 'Black Cards', 'Website': 'beberexha.com'}
# Sidebar found. Extracting information...
# {'Born': 'Rebbeca Marie Gomez [1] [2] ( 1997-03-02 ) March 2, 1997 (age\xa026) [2] Inglewood, California , U.S. [3] [4]', 'Other\xa0names': 'Becky Gomez [4]', 'Occupations': 'Singer actress', 'Years\xa0active': '2008–present', 'Organisation': 'Treslúce Beauty', 'Works': 'Discography songs performances videography', 'Awards': 'Full list', 'Genres': 'Hip hop R&B pop reggaeton [5] latin dance-pop pop-rap [6] [7] [8]', 'Instruments': 'Vocals', 'Labels': 'Kemosabe RCA Sony Latin', 'Website': 'iambeckyg .com'}
# Sidebar found. Extracting information...
# {'Born': 'Beyonce Giselle Knowles [a] ( 1981-09-04 ) September 4, 1981 (age\xa042) Houston , Texas, U.S.', 'Other\xa0names': 'Harmonies by The Hive [1] Queen B [2] Third Ward Trill [3]', 'Occupations': 'Singer songwriter record producer businesswoman dancer actress director philanthropist', 'Years\xa0active': '1997–present', 'Works': 'Albums [b] singles songs videos performances', 'Title': 'Founder, chairwoman, and CEO of Parkwood Entertainment Co-founder, CEO, and owner of Ivy Park', 'Spouse': 'Jay-Z \u200b ( m. 2008 ) \u200b', 'Children': '3, including Blue Ivy', 'Parents': 'Mathew Knowles Tina Lawson', 'Relatives': 'Solange Knowles (sister) Angela Beyincé (cousin)', 'Awards': 'Full list', 'Genres': 'R&B pop hip hop', 'Instrument(s)': 'Vocals piano', 'Labels': 'Parkwood Columbia Music World', 'Member of': 'The Carters', 'Formerly of': "Destiny's Child", 'Website': 'beyonce .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Sean Michael Leonard Anderson', 'Born': '( 1988-03-25 ) March 25, 1988 (age\xa035) Santa Monica, California , U.S.', 'Origin': 'Detroit , Michigan , U.S.', 'Genres': 'Hip hop', 'Occupation(s)': 'Rapper songwriter record producer actor', 'Years active': '2007–present', 'Labels': 'Don Life FF to Def Roc Nation Def Jam GOOD (former) [1]', 'Member of': 'Twenty88', 'Children': '1', 'Website': 'uknowbigsean .com'}
# Sidebar found. Extracting information...
# {'Born': "Billie Eilish Pirate Baird O'Connell ( 2001-12-18 ) December 18, 2001 (age\xa021) Los Angeles, California, U.S.", 'Occupations': 'Singer songwriter actress', 'Years\xa0active': '2015–present', 'Works': 'Discography songs recorded', 'Parent': 'Maggie Baird (mother)', 'Relatives': "Finneas O'Connell (brother) Brian Baird (uncle)", 'Awards': 'Full list', 'Genres': 'Pop alt-pop electropop pop rock [1]', 'Instrument(s)': 'Vocals guitar piano ukulele', 'Labels': 'Darkroom Interscope Polydor', 'Website': 'billieeilish .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'William Matthew Currington', 'Born': '( 1973-11-19 ) November 19, 1973 (age\xa050) Savannah, Georgia , U.S.', 'Origin': 'Rincon, Georgia , U.S.', 'Genres': 'Country country pop country rock', 'Occupation(s)': 'Singer songwriter', 'Instrument(s)': 'Vocals guitar', 'Years active': '1996–present', 'Labels': 'Mercury Nashville', 'Website': 'billycurrington .com'}
# Sidebar found. Extracting information...
# {'Born': 'William Martin Joel ( 1949-05-09 ) May 9, 1949 (age\xa074) New York City , U.S.', 'Other\xa0names': 'The Piano Man', 'Occupations': 'Singer songwriter pianist', 'Years\xa0active': '1964–present', 'Spouses': 'Elizabeth Weber Small \u200b \u200b ( m. 1973; div. 1982 ) \u200b Christie Brinkley \u200b \u200b ( m. 1985 ; div. 1994 ) \u200b Katie Lee \u200b \u200b ( m. 2004 ; div. 2009 ) \u200b Alexis Roderick \u200b ( m. 2015 ) \u200b', 'Children': '3, including Alexa Ray', 'Relatives': 'Alexander Joel (half-brother) Karl Amson Joel (grandfather)', 'Origin': 'Hicksville, New York , U.S.', 'Genres': 'Rock [1] [2] soft rock [3] pop rock [2] [2]', 'Instrument(s)': 'Vocals piano', 'Labels': 'Columbia Family\xa0Productions Sony\xa0Classical', 'Member of': 'Billy Joel Band', 'Website': 'billyjoel .com'}
# Sidebar found. Extracting information...
# {'Born': '( 1961-08-25 ) August 25, 1961 (age\xa062) Flatwoods, Kentucky , U.S.', 'Education': 'Georgetown College', 'Occupations': 'Singer songwriter actor', 'Years\xa0active': '1989–present', 'Spouses': 'Cindy Smith \u200b \u200b ( m. 1986; div. 1991) \u200b Tish Finley \u200b \u200b ( m. 1993; div. 2023) \u200b Firerose \u200b ( m. 2023) \u200b', 'Children': '6, including Brandi , Trace , Miley and Noah Cyrus', 'Parent': 'Ron Cyrus (father)', 'Awards': 'Full list', 'Genres': 'Country country pop [1]', 'Instrument(s)': 'Vocals guitar', 'Labels': 'Mercury Monument Madacy Word Curb Warner Bros. New Door UMe Walt Disney Lyric Street Buena Vista Broken Bow', 'Formerly of': 'Brother Clyde', 'Website': 'billyraycyrus .com'}
# Sidebar found. Extracting information...
# {'Born': 'Blake Tollison Shelton ( 1976-06-18 ) June 18, 1976 (age\xa047) Ada, Oklahoma , U.S.', 'Occupations': 'Singer television personality', 'Years\xa0active': '2001–present', 'Spouses': 'Kaynette Gern \u200b \u200b ( m. 2003; div. 2006) \u200b Miranda Lambert \u200b \u200b ( m. 2011 ; div. 2015 ) \u200b Gwen Stefani \u200b ( m. 2021 ) \u200b', 'Origin': 'Nashville, Tennessee , U.S.', 'Genres': 'Country', 'Instrument(s)': 'Vocals, guitar', 'Labels': 'Giant Warner Music Nashville Reprise Nashville Ten Point', 'Website': 'blakeshelton .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'James Lee Baker', 'Born': '( 1996-05-19 ) May 19, 1996 (age\xa027) Memphis, Tennessee , U.S.', 'Genres': 'Hip hop trap [1]', 'Occupation(s)': 'Rapper songwriter', 'Years active': '2012–present', 'Labels': 'Bloc Nation Foundation Interscope', 'Children': '1', 'Website': 'blocboy .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Johnathan Jamall Porter [1]', 'Also known as': 'Blueface Bleedem', 'Born': '( 1997-01-20 ) January 20, 1997 (age\xa026) Los Angeles , California , U.S.', 'Genres': 'Hip hop trap West Coast hip hop', 'Occupation(s)': 'Rapper', 'Years active': '2017–present', 'Labels': 'Cash Money West Republic Fifth Amendment E1', 'Children': '3', 'Website': 'blueface .shop .capthat .com'}
# Sidebar found. Extracting information...
# {'Also known as': 'Bob Marley & the Wailers, The Teenagers, The Wailing Rudeboys, The Wailing Wailers, The Wailers', 'Origin': 'Kingston , Jamaica', 'Genres': 'Roots reggae · ska · rocksteady · R&B', 'Discography': 'Bob Marley and the Wailers discography', 'Years active': '1963–1981', 'Labels': "Studio One , Wail'n Soul'm, Tuff Gong , Beverley's , Upsetter , Island , JAD", 'Past members': 'Peter Tosh Bunny Wailer Junior Braithwaite Cherry Smith Beverley Kelso Constantine Walker Aston Barrett Carlton Barrett Earl Lindo Tyrone Downie Rita Marley Marcia Griffiths Judy Mowatt Al Anderson Alvin Patterson Earl "Chinna" Smith Donald Kinsey Junior Marvin Nathaniel Ian Wynter', 'Website': 'bobmarley .com'}
# Sidebar found. Extracting information...
# {'Origin': 'Sayreville, New Jersey , U.S.', 'Genres': 'Glam metal hard rock arena rock pop rock', 'Discography': 'Bon Jovi discography', 'Years active': '1983–present', 'Labels': 'Island Mercury Vertigo', 'Members': 'Jon Bon Jovi David Bryan Tico Torres Phil X Hugh McDonald', 'Past members': 'Alec John Such Dave Sabo Richie Sambora', 'Website': 'bonjovi .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Shad Gregory Moss', 'Also known as': "Lil' Bow Wow Kid Gangsta", 'Born': '( 1987-03-09 ) March 9, 1987 (age\xa036) Columbus, Ohio , U.S.', 'Genres': 'Hip hop', 'Occupation(s)': 'Rapper songwriter actor', 'Years active': '1993–present', 'Labels': 'LBW Bad Boy (current) Cash Money Republic Sony Urban Columbia So So Def', 'Children': '2', 'Website': 'bwapparel .com'}
# Sidebar found. Extracting information...
# {'Born': 'Bradley Douglas Paisley ( 1972-10-28 ) October 28, 1972 (age\xa051) Glen Dale, West Virginia , U.S.', 'Occupations': 'Singer songwriter guitarist', 'Spouse': 'Kimberly Williams \u200b ( m. 2003) \u200b', 'Children': '2', 'Genres': 'Country', 'Instruments': 'Vocals guitar bass mandolin dobro banjo', 'Years active': '1998–present', 'Labels': 'Arista Nashville EMI Nashville', 'Website': 'bradpaisley .com'}
# Sidebar found. Extracting information...
# {'Born': 'Bradley Charles Cooper ( 1975-01-05 ) January 5, 1975 (age\xa048) Abington Township, Pennsylvania , U.S. [1]', 'Alma\xa0mater': 'Georgetown University ( BA ) The New School ( MFA )', 'Occupations': 'Actor film director film producer screenwriter', 'Years\xa0active': '1999–present', 'Works': 'Full list', 'Spouse': 'Jennifer Esposito \u200b \u200b ( m. 2006; div. 2007) \u200b', 'Partner(s)': 'Irina Shayk (2015–2019)', 'Children': '1', 'Awards': 'Full list'}
# Sidebar found. Extracting information...
# {'Birth name': 'Brantley Keith Gilbert [1]', 'Born': '( 1985-01-20 ) January 20, 1985 (age\xa038) [2]', 'Origin': 'Jefferson, Georgia , U.S. [2]', 'Genres': 'Country country rock southern rock hard rock', 'Occupation(s)': 'Singer songwriter record producer', 'Instrument(s)': 'Vocals guitar', 'Years active': '2005–present', 'Labels': 'Average Joes Valory', 'Website': 'brantleygilbert .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Christopher Brent Wood [1]', 'Born': '( 1995-09-19 ) September 19, 1995 (age\xa028) [2] [3] Columbia, Maryland , U.S.', 'Genres': 'R&B', 'Occupation(s)': 'Singer songwriter record producer', 'Years active': '2013–present', 'Labels': 'Lost Kids Venice Stem ISO Supremacy UnitedMasters', 'Website': 'brentfaiyaz .com'}
# Disambiguation page detected. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/Brett_Young_(singer)
# Sidebar found. Extracting information...
# {'Birth name': 'Brett Charles Young', 'Born': '( 1981-03-23 ) March 23, 1981 (age\xa042) [1] Anaheim , Orange County, California , United States', 'Genres': 'Country pop', 'Occupation(s)': 'Singer songwriter guitarist', 'Years active': '2007–present', 'Labels': 'BMLG', 'Website': 'www .brettyoungmusic .com'}
# Sidebar found. Extracting information...
# {'Born': 'Britney Jean Spears ( 1981-12-02 ) December 2, 1981 (age\xa041) McComb, Mississippi , U.S.', 'Education': 'Professional Performing Arts School Parklane Academy [1]', 'Occupations': 'Singer songwriter dancer actress', 'Years\xa0active': '1992–present', 'Works': 'Discography songs videography', 'Spouses': 'Jason Allen Alexander \u200b \u200b ( m. 2004 ; ann. 2004 ) \u200b Kevin Federline \u200b \u200b ( m. 2004 ; div. 2007 ) \u200b Sam Asghari \u200b \u200b ( m. 2022 ; sep. 2023 ) \u200b', 'Children': '2', 'Parents': 'Lynne Spears Jamie Spears', 'Relatives': 'Bryan Spears (brother) Jamie Lynn Spears (sister)', 'Awards': 'Full list', 'Genres': 'Pop dance-pop electropop teen pop', 'Instruments': 'Vocals', 'Labels': 'Jive RCA', 'Formerly of': 'Innosense', 'Website': 'www .britneyspears .com www .britney .com'}
# Sidebar found. Extracting information...
# {'Born': '( 1949-09-23 ) September 23, 1949 (age\xa074) Long Branch, New Jersey , U.S.', 'Occupations': 'Singer songwriter musician', 'Spouses': 'Julianne Phillips \u200b \u200b ( m. 1985; div. 1989) \u200b Patti Scialfa \u200b \u200b ( m. 1991) \u200b', 'Children': '3, including Jessica', 'Relatives': 'Pamela Springsteen (sister)', 'Genres': 'Rock Americana heartland rock pop rock [1]', 'Instrument(s)': 'Vocals guitar', 'Discography': 'Bruce Springsteen discography', 'Years active': '1964–present', 'Labels': 'Columbia', 'Member of': 'E Street Band', 'Website': 'brucespringsteen .net'}
# Sidebar found. Extracting information...
# {'Born': 'Peter Gene Hernandez ( 1985-10-08 ) October 8, 1985 (age\xa038) Honolulu , Hawaii, U.S.', 'Occupations': 'Singer songwriter musician record producer dancer director', 'Years\xa0active': '1992, 2004–present', 'Partner': 'Jessica Caban (2011–present)', 'Awards': 'Full list', 'Genres': 'Pop R&B funk soul', 'Instruments': 'Vocals guitar piano keyboards drums bass ukulele congas', 'Discography': 'Bruno Mars discography', 'Labels': 'Universal Motown Atlantic Elektra', 'Member of': 'The Hooligans Silk Sonic', 'Formerly of': 'The Smeezingtons', 'Website': 'brunomars .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Bryson Djuan Tiller', 'Also known as': 'Pen Griffey [1]', 'Born': '( 1993-01-02 ) January 2, 1993 (age\xa030) Louisville, Kentucky , U.S.', 'Genres': 'R&B hip hop soul trap [2]', 'Occupation(s)': 'Singer rapper songwriter', 'Years active': '2011–present', 'Labels': 'RCA', 'Children': '2', 'Website': 'trapsoul .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Christopher Daniel Soriano Jr.', 'Born': '( 1997-01-04 ) January 4, 1997 (age\xa026) Staten Island , New York , U.S.', 'Genres': 'Hip hop trap drill', 'Years active': '2017–present', 'Labels': 'AWAL Cruz Control Warner [1] [2]'}
# Sidebar found. Extracting information...
# {'Born': 'Chukwuka Chukwuma Ekweani [1] ( 1995-07-16 ) 16 July 1995 (age\xa028) Kaduna , Nigeria', 'Nationality': 'Nigerian', 'Years\xa0active': '2016–present', 'Agent': 'Asa Asika', 'Works': 'Discography', 'Genres': 'Afrobeats R&B Pop Alté', 'Instrument(s)': 'Vocals piano drums guitar', 'Labels': 'Warner Music Africa Atlantic', 'Website': 'ckay-music .com'}
# Sidebar found. Extracting information...
# {'Born': 'Adam Richard Wiles ( 1984-01-17 ) 17 January 1984 (age\xa039) Dumfries , Scotland', 'Other\xa0names': 'Love Regenerator [1]', 'Occupations': 'DJ record producer singer songwriter', 'Years\xa0active': '2002–present', 'Spouse': 'Vick Hope \u200b ( m. 2023) \u200b', 'Awards': 'List of awards and nominations', 'Genres': 'EDM [2] electro house [3] electropop [4] dance-pop [5] nu-disco [3]', 'Instrument(s)': 'Piano keyboards synthesiser guitar bass guitar sampler sequencer vocals', 'Labels': "Fly Eye Columbia Ministry of Sound Ultra Roc Nation Deconstruction Spinnin' Records", 'Website': 'calvinharris .com'}
# Sidebar found. Extracting information...
# {'Born': 'Karla Camila Cabello Estrabao ( 1997-03-03 ) March 3, 1997 (age\xa026) Cojímar , Havana , Cuba', 'Years\xa0active': '2012–present', 'Works': 'Solo discography Fifth Harmony discography ( songs )', 'Awards': 'Full list', 'Genres': 'Pop Latin R&B', 'Instrument(s)': 'Vocals', 'Labels': 'Epic Syco Interscope', 'Formerly of': 'Fifth Harmony', 'Website': 'camilacabello .com'}
# Disambiguation page detected. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/Capital_Cities_(band)
# Sidebar found. Extracting information...
# {'Origin': 'Los Angeles , California , US', 'Genres': 'Indie pop [1] dance-pop [2] synth-pop [3] indietronica [4]', 'Years active': '2008–present [5] [2]', 'Labels': 'Roc Nation Lazy Hooks Capitol', 'Members': 'Ryan Merchant Sebu Simonian', 'Website': 'capitalcitiesmusic .com'}
# Sidebar found. Extracting information...
# {'Born': 'Belcalis Marlenis Almánzar ( 1992-10-11 ) October 11, 1992 (age\xa031) New York City , U.S.', 'Other\xa0names': 'Belcalis Almánzar-Cephus', 'Education': 'Borough of Manhattan Community College', 'Occupations': 'Rapper songwriter actress', 'Years\xa0active': '2015–present', 'Spouse': 'Offset \u200b ( m. 2017) \u200b', 'Children': '2', 'Awards': 'Full list', 'Genres': 'Hip hop trap', 'Instrument(s)': 'Vocals', 'Labels': 'KSR [1] Atlantic', 'Website': 'cardib .com'}
# Sidebar found. Extracting information...
# {'Born': '( 1985-11-21 ) November 21, 1985 (age\xa038) Mission , British Columbia , Canada', 'Genres': 'Pop disco pop rock folk', 'Occupation(s)': 'Singer songwriter musician', 'Instrument(s)': 'Vocals guitar keyboards', 'Years active': '2007–present', 'Labels': '604 Schoolboy Interscope MapleMusic (former) Polydor [1]', 'Website': 'carlyraemusic .com'}
# Sidebar found. Extracting information...
# {'Born': 'Carrie Marie Underwood ( 1983-03-10 ) March 10, 1983 (age\xa040) Muskogee, Oklahoma , U.S.', 'Alma\xa0mater': 'Northeastern State University ( BA )', 'Occupations': 'Singer songwriter', 'Years\xa0active': '2005–present', 'Works': 'Discography songs', 'Spouse': 'Mike Fisher \u200b ( m. 2010) \u200b', 'Children': '2', 'Awards': 'Full list', 'Genres': 'Country country pop country rock gospel', 'Instrument(s)': 'Vocals', 'Labels': '19 Arista Arista Nashville Capitol Nashville', 'Website': 'carrieunderwoodofficial .com'}
# Sidebar found. Extracting information...
# {'Born': 'Casandra Elizabeth Ventura ( 1986-08-26 ) August 26, 1986 (age\xa037) New London, Connecticut , U.S.', 'Occupations': 'Singer songwriter model actress dancer', 'Years\xa0active': '2004–present', 'Spouse': 'Alex Fine \u200b ( m. 2019) \u200b', 'Partner': 'Sean Combs (2007–2018)', 'Children': '2', 'Height': '1.69\xa0m (5\xa0ft 7\xa0in) [1]', 'Eye color': 'Brown', 'Agency': 'Wilhelmina', 'Genres': 'R&B [2] pop [3] hip hop [4]', 'Labels': 'NextSelection Bad Boy Empire Interscope', 'Website': 'cassiesuper .com'}
# Sidebar found. Extracting information...
# {'Origin': 'Daytona Beach, Florida , U.S.', 'Genres': 'Contemporary Christian , Christian rock', 'Years active': '1999–present', 'Labels': 'Beach Street , Reunion , Sony BMG', 'Members': 'Mark Hall Juan DeVevo Josh Mix Melodee DeVevo Megan Garrett Jack Williams John Michael Hall', 'Past members': 'Chris Huffman Brian Scoggin Andy Williams Hector Cervantes', 'Website': 'castingcrowns .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Thomas DeCarlo Callaway', 'Also known as': 'Thomas Burton [1]', 'Born': '( 1975-05-30 ) May 30, 1975 (age\xa048) [2] Atlanta , Georgia, U.S.', 'Genres': 'Hip hop R&B soul funk gospel', 'Occupation(s)': 'Singer rapper songwriter record producer actor', 'Discography': 'Recording production', 'Years active': '1991–present', 'Labels': 'Easy Eye Atlantic BMG Warner Bros. Roadrunner Elektra Arista LaFace', 'Member of': 'Dungeon Family Gnarls Barkley Goodie Mob', 'Children': '1', 'Website': 'ceelogreen .com'}
# Sidebar found. Extracting information...
# {'Born': 'Céline Marie Claudette Dion ( 1968-03-30 ) 30 March 1968 (age\xa055) Charlemagne, Quebec , Canada', 'Occupations': 'Singer actress entrepreneur philanthropist', 'Years\xa0active': '1980–2022 (Hiatus)', 'Spouse': 'René Angélil \u200b \u200b ( m. 1994; died\xa02016) \u200b', 'Children': '3', 'Parent': 'Thérèse Dion (mother)', 'Awards': 'Full list', 'Genres': 'Pop R&B chanson soft rock gospel', 'Instrument(s)': 'Vocals', 'Labels': 'CBS Epic Columbia 550 Legacy', 'Website': 'celinedion .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Hakeem Temidayo Seriki [1]', 'Born': '( 1979-11-28 ) November 28, 1979 (age\xa043) Washington, D.C. , U.S.', 'Origin': 'Houston, Texas , U.S.', 'Genres': 'Hip hop Southern hip hop', 'Occupation(s)': 'Rapper songwriter entrepreneur', 'Years active': '1997–present', 'Labels': 'Chamillitary Swishahouse Paid in Full Universal Motown Universal', 'Formerly of': "The Color Changin' Click", 'Children': '1', 'Website': 'chamillionaire .com'}
# Sidebar found. Extracting information...
# {'Born': 'Chancelor Johnathan Bennett ( 1993-04-16 ) April 16, 1993 (age\xa030) [1] Chicago , Illinois , U.S.', 'Other\xa0names': 'Chance [2]', 'Education': 'Jones College Prep High School', 'Occupations': 'Rapper singer songwriter record producer', 'Years\xa0active': '2011–present', 'Organization': 'SocialWorks', 'Works': 'Discography production', 'Spouse': 'Kirsten Corley \u200b ( m. 2019 ) \u200b', 'Children': '2', 'Relatives': 'Taylor Bennett (brother)', 'Awards': 'Full list', 'Genres': 'Hip hop alternative hip hop R&B', 'Instruments': 'Vocals', 'Formerly of': 'Savemoney The Social Experiment', 'Website': 'chanceraps .com'}
# Sidebar found. Extracting information...
# {'Born': 'Charlotte Emma Aitchison ( 1992-08-02 ) 2 August 1992 (age\xa031) Cambridge , England', 'Occupations': 'Singer songwriter', 'Years\xa0active': '2006–present', 'Works': 'Discography songs written performances', 'Awards': 'Full list', 'Genres': 'Electropop dance-pop experimental pop hyperpop pop-punk', 'Labels': 'Vroom Vroom Warner Asylum Atlantic Iamsound', 'Website': 'charlixcx .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Charles Otto Puth Jr.', 'Born': '( 1991-12-02 ) December 2, 1991 (age\xa031) Rumson, New Jersey , U.S.', 'Alma\xa0mater': 'Berklee College of Music ( BM )', 'Genres': 'Pop [1] R&B [2]', 'Occupation(s)': 'Singer songwriter record producer', 'Instrument(s)': 'Vocals piano', 'Years active': '2009–present', 'Labels': 'APG Atlantic Loudr eleveneleven', 'Website': 'charlieputh .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Orlando Javier Valle Vega', 'Also known as': 'Chencho Little J Chencho D Chenchito Chencho Man [1]', 'Born': '( 1979-02-19 ) February 19, 1979 (age\xa044) Guayama, Puerto Rico', 'Genres': 'Reggaeton', 'Occupation(s)': 'Singer songwriter record producer', 'Years active': '1999–present', 'Labels': 'Pina Sony Latin', 'Formerly of': 'Plan B', 'Website': 'chenchocorleone .com'}
# Sidebar found. Extracting information...
# {'Born': 'Cherilyn Sarkisian ( 1946-05-20 ) May 20, 1946 (age\xa077) El Centro, California , US', 'Other\xa0names': 'Cheryl LaPiere Cher Bono Cherilyn Sarkisian La Piere Bono Allman', 'Occupations': 'Singer actress television personality', 'Years\xa0active': '1963–present', 'Works': 'Albums singles duo discography videography filmography concerts', 'Spouses': 'Sonny Bono \u200b \u200b ( m. 1964; div. 1975) \u200b Gregg Allman \u200b \u200b ( m. 1975; div. 1979) \u200b', 'Children': 'Chaz Bono Elijah Blue Allman', 'Parent': 'Georgia Holt (mother)', 'Awards': 'Full list', 'Genres': 'Pop rock folk disco dance', 'Instrument(s)': 'Vocals', 'Labels': 'Atco Casablanca Columbia Geffen Imperial Kapp MCA Reprise United Artists Warner', 'Formerly of': 'Sonny & Cher', 'Website': 'cher .com'}
# Sidebar found. Extracting information...
# {'Born': 'Donald McKinley Glover Jr. ( 1983-09-25 ) September 25, 1983 (age\xa040) Edwards Air Force Base, California , U.S.', 'Other\xa0names': 'Childish Gambino mcDJ', 'Education': 'New York University ( BFA )', 'Occupations': 'Actor comedian singer rapper writer producer director', 'Years\xa0active': '2005–present', 'Partner': 'Michelle White (2015–present)', 'Children': '3', 'Relatives': 'Stephen Glover (brother)', 'Genres': 'Hip hop funk R&B soul psychedelia indie pop', 'Subject(s)': 'African-American culture American politics current events everyday life pop culture the internet the future existentialism human sexuality', 'Origin': 'Stone Mountain, Georgia , U.S.', 'Instrument(s)': 'Vocals', 'Labels': 'mcDJ Wolf+Rothstein Liberator RCA (current) Glassnote (former)', 'Website': 'donaldgloverpresents .com'}
# Sidebar found. Extracting information...
# {'Born': 'Christopher Maurice Brown ( 1989-05-05 ) May 5, 1989 (age\xa034) Tappahannock, Virginia , U.S.', 'Other\xa0names': 'C. Sizzle Breezy CB [1]', 'Education': 'Essex High School', 'Occupations': 'Singer songwriter rapper dancer actor', 'Years\xa0active': '2002–present', 'Works': 'Discography production videography', 'Awards': 'Full list', 'Genres': 'R&B hip hop pop', 'Instrument(s)': 'Vocals', 'Labels': 'CBE Jive RCA', 'Website': 'chrisbrownworld .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Christopher Alvin Stapleton', 'Born': '( 1978-04-15 ) April 15, 1978 (age\xa045) Lexington, Kentucky , U.S.', 'Origin': 'Nashville, Tennessee , U.S.', 'Genres': 'Country soul Southern rock bluegrass', 'Occupation(s)': 'Singer-songwriter musician record producer', 'Instrument(s)': 'Vocals guitar', 'Years active': '2001−present', 'Labels': 'Mercury Nashville', 'Formerly of': 'The SteelDrivers The Jompson Brothers', 'Spouse(s)': 'Morgane Hayes \u200b ( m. 2007) \u200b', 'Website': 'chrisstapleton .com'}
# Disambiguation page detected. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/Chris_Young_(singer)
# Sidebar found. Extracting information...
# {'Birth name': 'Christopher Alan Young [1]', 'Born': '( 1985-06-12 ) June 12, 1985 (age\xa038) [2]', 'Origin': 'Murfreesboro, Tennessee , U.S.', 'Genres': 'Country', 'Occupation(s)': 'Singer songwriter', 'Instrument(s)': 'Vocals guitar', 'Years active': '2002–present', 'Labels': 'RCA Nashville', 'Website': 'chrisyoungcountry .com'}
# Sidebar found. Extracting information...
# {'Born': 'Christina María Aguilera ( 1980-12-18 ) December 18, 1980 (age\xa042) New York City, US', 'Other\xa0names': 'Xtina Baby Jane', 'Occupations': 'Singer songwriter actress television personality', 'Years\xa0active': '1993–present', 'Organizations': 'Christina Aguilera Fragrances MX Productions', 'Works': 'Discography songs videography concerts and tours', 'Spouse': 'Jordan Bratman \u200b \u200b ( m. 2005 ; div. 2011 ) \u200b', 'Partner': 'Matthew Rutler ( eng. 2014)', 'Children': '2', 'Awards': 'Full list', 'Genres': 'Pop R&B soul', 'Instruments': 'Vocals', 'Labels': 'RCA Sony Latin Legacy', 'Website': 'christinaaguilera .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Christina Judith Perri', 'Born': '( 1986-08-19 ) August 19, 1986 (age\xa037) Bensalem, Pennsylvania , U.S.', 'Genres': 'Pop pop rock', 'Occupation(s)': 'Singer songwriter', 'Instrument(s)': 'Vocals guitar piano keyboards', 'Labels': 'Atlantic Elektra', 'Website': 'christinaperri .com'}
# Sidebar found. Extracting information...
# {'Born': 'Ciara Princess Harris ( 1985-10-25 ) October 25, 1985 (age\xa038) Fort Hood , Texas , U.S.', 'Education': 'Riverdale High School', 'Occupations': 'Singer songwriter dancer actress businesswoman model', 'Years\xa0active': '2001–present', 'Spouse': 'Russell Wilson \u200b ( m. 2016) \u200b', 'Children': '3', 'Awards': 'Full list', 'Origin': 'Atlanta , Georgia , U.S.', 'Genres': 'R&B pop hip hop dance crunk', 'Instrument(s)': 'Vocals', 'Labels': "Uptown Republic ADA Beauty Marks/Vydia Epic Jive Zomba LaFace Sho'nuff"}
# Sidebar found. Extracting information...
# {'Born': 'Caresha Romeka Brownlee ( 1994-02-11 ) February 11, 1994 (age\xa029) Miami , Florida , U.S. Jatavia Shakara Johnson ( 1992-12-03 ) December 3, 1992 (age\xa030) Vero Beach, Florida , U.S.', 'Origin': 'Miami , Florida , U.S.', 'Genres': 'Hip hop Southern hip hop trap', 'Years active': '2017–present', 'Labels': 'Quality Control Motown Capitol', 'Members': 'Yung Miami JT', 'Website': '305citygirls .com'}
# Sidebar found. Extracting information...
# ...
# Sidebar found. Extracting information...
# {'Origin': 'Pasadena, California , U.S.', 'Genres': 'Hard rock heavy metal pop rock AOR glam metal', 'Discography': 'Van Halen discography', 'Years active': '1973–2020 [1]', 'Labels': 'Warner Bros. Interscope', 'Spinoffs': 'Mammoth WVH', 'Past members': 'Eddie Van Halen Alex Van Halen David Lee Roth Mark Stone Michael Anthony Sammy Hagar Gary Cherone Wolfgang Van Halen', 'Website': 'van-halen .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'James Gabriel Keogh', 'Born': '( 1987-12-01 ) 1 December 1987 (age\xa035) Melbourne , Victoria, Australia', 'Origin': "St Kevin's College Monash University", 'Genres': 'Indie pop indie folk [1]', 'Occupations': 'Singer songwriter', 'Instruments': 'Vocals ukulele guitar piano', 'Years active': '2013–present', 'Labels': 'Liberation Infectious F-Stop Atlantic', 'Spouse(s)': 'Selen Us ( m. 2023)', 'Website': 'www .vancejoy .com', 'Personal information': 'Australian rules footballer Australian rules football career Personal information Position(s) Defender Playing career Years Club Games (Goals) 2008–2009 Coburg 28', 'Position(s)': 'Defender', 'Years': 'Club', '2008–2009': 'Coburg'}
# Sidebar found. Extracting information...
# {'Origin': 'Cincinnati , Ohio , U.S.', 'Genres': 'Pop rock [1] synth-rock [2] indie rock [3] new wave [4] dance-rock [3]', 'Years active': '2006–2023 [a]', 'Labels': 'RCA', 'Members': 'Nicholas Petricca Sean Waugaman Eli Maiman', 'Past members': 'Adam Reifsnyder Sam Cole Ricky Human Nick Lerangis Kevin Ray Chris Robinson Adrian Galvin', 'Website': 'walkthemoonband .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Juaquin James Malphurs', 'Born': '( 1986-05-31 ) May 31, 1986 (age\xa037) New York City , U.S.', 'Origin': 'Atlanta, Georgia , U.S.', 'Genres': 'Hip hop trap', 'Occupation(s)': 'Rapper songwriter', 'Years active': '2008–present', 'Labels': '36 Brick House Dusk Til Dawn E1 Brick Squad Monopoly 1017 Brick Squad Asylum Warner Bros. RBC Mizay So Icey', 'Spouse(s)': 'Tammy Rivera \u200b ( m. 2014) \u200b', 'Website': 'wakaflocka .com'}
# Disambiguation page detected. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/Wale_(rapper)
# Sidebar found. Extracting information...
# {'Birth name': 'Olubowale Victor Akintimehin', 'Also known as': 'Ralph Folarin [1]', 'Born': '( 1984-09-21 ) September 21, 1984 (age\xa039) Washington, D.C. , U.S.', 'Origin': 'Gaithersburg, Maryland , U.S.', 'Genres': 'Hip hop', 'Occupations': 'Rapper singer songwriter', 'Years active': '2005–present', 'Labels': 'Def Jam [2] Every Blue Moon Maybach Music Warner Bros. Atlantic Roc Nation Interscope Allido The Board Administration', 'Formerly of': 'All City Chess Club', 'Children': '2', 'Website': 'walemusic .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Charles Edgar Walker Hayes [1]', 'Born': '( 1979-12-27 ) December 27, 1979 (age\xa043) [2] [3]', 'Origin': 'Mobile, Alabama , U.S. [4]', 'Genres': 'Country pop [3] bro-country [5]', 'Occupation(s)': 'Singer songwriter', 'Instrument(s)': 'Vocals guitar piano', 'Years active': '2010–present', 'Labels': 'Capitol Monument', 'Spouse(s)': 'Laney Beville \u200b ( m. 2004) \u200b'}
# Sidebar found. Extracting information...
# {'Birth name': 'Michael Wansley', 'Also known as': 'TeeWanz', 'Born': '( 1961-10-09 ) October 9, 1961 (age\xa062) Seattle, Washington , U.S.', 'Genres': 'Hip hop alternative hip hop R&B pop', 'Occupation(s)': 'Singer songwriter rapper', 'Instrument(s)': 'Vocals bass guitar', 'Years active': '1980–present', 'Website': 'thewanz .com'}
# Sidebar found. Extracting information...
# {'Born': 'Whitney Elizabeth Houston ( 1963-08-09 ) August 9, 1963 Newark, New Jersey , U.S.', 'Died': 'February 11, 2012 (2012-02-11) (aged\xa048) Beverly Hills, California , U.S.', 'Burial place': 'Fairview Cemetery , Westfield, New Jersey', 'Education': 'Mount Saint Dominic Academy', 'Occupations': 'Singer actress producer model', 'Years\xa0active': '1977–2012', 'Spouse': 'Bobby Brown \u200b \u200b ( m. 1992; div. 2007) \u200b', 'Children': 'Bobbi Kristina Brown', 'Parent': 'Cissy Houston (mother)', 'Relatives': 'Gary Garland (half-brother) Dionne Warwick (cousin) Dee Dee Warwick (cousin) Leontyne Price (cousin)', 'Awards': 'Accolades records', 'Genres': 'R&B pop dance-pop soul gospel', 'Labels': 'Arista RCA', 'Website': 'whitneyhouston .com'}
# Sidebar found. Extracting information...
# {'Born': 'Cameron Jibril Thomaz ( 1987-09-08 ) September 8, 1987 (age\xa036) Minot, North Dakota , U.S.', 'Education': 'Taylor Allderdice High School', 'Occupations': 'Rapper singer songwriter actor', 'Years\xa0active': '2005–present', 'Spouse': 'Amber Rose \u200b \u200b ( m. 2013; div. 2016) \u200b', 'Children': '1', 'Awards': 'Full list', 'Origin': 'Pittsburgh, Pennsylvania , U.S.', 'Genres': 'Hip hop pop rap trap', 'Discography': 'Wiz Khalifa discography', 'Labels': 'Taylor Gang Asylum Atlantic Warner Bros. Rostrum [1]', 'Member of': 'TGOD Mafia', 'Website': 'wizkhalifa .com'}
# Sidebar found. Extracting information...
# {'Also known as': 'Ambassadors XA', 'Origin': 'Ithaca , New York , United States', 'Genres': 'Alternative rock indie rock indie pop pop rock', 'Years active': '2009–present', 'Labels': 'Geffen Interscope KIDinaKORNER', 'Members': 'Sam Harris Casey Harris Adam Levin', 'Past members': 'Noah Feldshuh', 'Website': 'xambassadors .com'}
# Sidebar found. Extracting information...
# {'Born': 'Jahseh Dwayne Ricardo Onfroy ( 1998-01-23 ) January 23, 1998 Plantation, Florida , U.S.', 'Died': 'June 18, 2018 (2018-06-18) (aged\xa020) Deerfield Beach, Florida , U.S.', 'Cause\xa0of death': 'Murder (multiple gunshot wounds to the neck)', 'Resting place': 'Gardens of Boca Raton Memorial Park Boca Raton, Florida , U.S. [1]', 'Other\xa0names': 'X XXX Triple X Jah Young Dagger Dick [2]', 'Occupations': 'Rapper singer songwriter', 'Agent': 'Solomon Sobande [3]', 'Partner(s)': 'Geneva Ayala (2014–2016) Jenesis Sanchez (2017–2018) [4] [a]', 'Children': '1 [5] [b]', 'Origin': 'Broward County , Florida, U.S.', 'Genres': 'Music gaming vlogging', 'Years active': '2013–2018', 'Labels': 'Bad Vibes Forever Empire Capitol Caroline Columbia', 'Formerly of': 'Members Only', 'Channel': 'XXXTentacion', 'Years\xa0active': '2015–2018', 'Subscribers': '38.50\xa0million [12]', 'Total\xa0views': '9.65\xa0billion [12]', 'Creator Awards': 'Creator Awards 100,000 subscribers 2017 [13] 1,000,000 subscribers 2017 [13] 10,000,000 subscribers 2018 [13]', 'Website': 'xxxtentacion.com'}
# Disambiguation page detected. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/Young_Guns_(band)
# Sidebar found. Extracting information...
# {'Origin': 'High Wycombe , Buckinghamshire , England', 'Genres': 'Post-hardcore [1] alternative rock [2] [3] [4] alternative metal [4] hard rock [5]', 'Years active': '2008–present', 'Labels': 'Live Forever Wind-up PIAS Virgin EMI', 'Members': 'Gustav Wood Fraser Taylor John Taylor Simon Mitchell Ben Jolliffe', 'Past members': 'Chris Kamrada', 'Website': 'weareyoungguns .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Jamell Maurice Demons [1]', 'Also known as': 'Melly, Melvin', 'Born': '( 1999-05-01 ) May 1, 1999 (age\xa024)', 'Origin': 'Gifford, Florida , U.S.', 'Genres': 'Hip hop trap R&B', 'Occupation(s)': 'Rapper singer songwriter', 'Years active': '2016–2019', 'Labels': '300 Atlantic', 'Relatives': 'YNW BSlime (brother)', 'Website': 'ynw4life .com', 'Criminal status': 'Incarcerated since February 13, 2019', 'Criminal charge': 'Premeditated first-degree murder (x2)', 'Date apprehended': 'February 13, 2019', 'Imprisoned\xa0at': 'Broward County Jail, Fort Lauderdale, Florida , U.S.'}
# Sidebar found. Extracting information...
# {'Birth name': 'Noah Olivier Smith', 'Also known as': 'Twizzy Luh Geeky Kranky Kranky Luh Kranky Luh Tonkem', 'Born': '( 2000-02-26 ) February 26, 2000 (age\xa023) Irvine, California , U.S.', 'Origin': 'Portland, Oregon , U.S.', 'Genres': 'Hip hop trap rage cloud rap', 'Occupation(s)': 'Rapper singer songwriter record producer', 'Years active': '2015–present', 'Labels': 'Geffen Field Trip Empire Interscope', 'Website': 'yeatofficial .com'}
# Sidebar found. Extracting information...
# {'Born': 'Jay Wayne Jenkins ( 1977-09-28 ) September 28, 1977 (age\xa046) Columbia, South Carolina , U.S.', 'Other\xa0names': "Lil' J Young Jeezy The Snowman", 'Occupations': 'Rapper songwriter actor', 'Years\xa0active': '1997–present', 'Spouse': 'Jeannie Mai \u200b \u200b ( m. 2021 ; sep. 2023 ) \u200b', 'Children': '4', 'Awards': 'Full list', 'Origin': 'Hawkinsville, Georgia , U.S. [1]', 'Genres': 'Hip hop trap Southern hip hop gangsta rap', 'Labels': 'Island Def Jam CTE World Def Jam', 'Member of': 'U.S.D.A.', 'Formerly of': 'Boyz n da Hood', 'Website': 'jeezyofficial .com'}
# Sidebar found. Extracting information...
# {'Parent company': 'Universal Music Group', 'Founded': '2005 ; 18\xa0years ago ( 2005 )', 'Founder': 'Lil Wayne', 'Distributor(s)': 'Republic Records', 'Genre': 'Various, mainly hip hop', 'Country of origin': 'United States', 'Location': 'New Orleans , Louisiana', 'Official website': 'youngmoney .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Jeffery Lamar Williams II [1]', 'Also known as': 'SEX King Slime Thugger', 'Born': '( 1991-08-16 ) August 16, 1991 (age\xa032) Atlanta, Georgia , U.S.', 'Genres': 'Hip hop trap mumble rap [2] progressive hip hop [3]', 'Occupation(s)': 'Rapper singer songwriter', 'Years active': '2010–present [4]', 'Labels': 'YSL 300 Atlantic (current) Cash Money 1017 Brick Squad (former)', 'Member of': 'Bankroll Mafia Rich Gang', 'Partner(s)': 'Mariah the Scientist (2021–present)', 'Children': '6', 'Website': 'youngstonerliferecords .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Kentrell DeSean Gaulden', 'Also known as': 'NBA YoungBoy Top Lil Top YoungBoy YB AI YoungBoy AI', 'Born': '( 1999-10-20 ) October 20, 1999 (age\xa024) Baton Rouge, Louisiana , U.S.', 'Genres': 'Hip hop southern hip hop gangsta rap trap', 'Occupation(s)': 'Rapper singer songwriter', 'Years active': '2015–present', 'Labels': 'Never Broke Again Motown (current) Atlantic (former)', 'Spouse': 'Jazlyn Mychelle Hayes \u200b \u200b ( m. 2023 ) \u200b', 'Children': '11', 'Website': 'youngboynba .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Jeremy Biddle', 'Also known as': 'Bleu Vandross', 'Born': '( 1994-04-04 ) April 4, 1994 (age\xa029) Mobile, Alabama , U.S.', 'Genres': 'Hip hop R&B', 'Occupation(s)': 'Rapper singer-songwriter record producer', 'Years active': '2013–present', 'Labels': 'Vandross Interscope Epic Columbia Bad Azz Music Syndicate', 'Website': 'yungbleu .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Jasiel Amon Robinson [1] [2]', 'Born': '( 1980-09-20 ) September 20, 1980 (age\xa043) [1] Atlanta , Georgia , U.S.', 'Genres': 'Southern hip hop [3]', 'Occupation(s)': 'Rapper songwriter', 'Years active': '2003–present', 'Labels': 'Swagg Team Bad Boy Atlantic J Block RCA Polo Grounds', 'Spinoff of': 'Nitti Beatz Puff Daddy', 'Children': '9+', 'Website': 'yungceoj .com', 'Spouse(s)': 'Kendra Robinson (m. 2021)'}
# Sidebar found. Extracting information...
# {'Origin': 'Atlanta, Georgia , U.S.', 'Genres': 'Country rock [1] [2] country pop [2] Southern rock [3] reggae [4]', 'Years active': '2002–present', 'Labels': 'Bigger Picture Southern Ground Atlantic RPM Big Machine Republic Elektra BMG', 'Spinoffs': 'Sir Rosevelt', 'Members': 'Zac Brown Coy Bowles Clay Cook Daniel de los Reyes Matt Mangano Jimmy De Martini Chris Fryar John Driskell Hopkins Caroline Jones', 'Past members': 'Tim Ussery Jacob Lawson Marcus Petruska Joel Williams [5] [6]', 'Website': 'zacbrownband .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Zachary Lane Bryan [1]', 'Born': '( 1996-04-02 ) April 2, 1996 (age\xa027) Okinawa , Japan', 'Origin': 'Oologah, Oklahoma , U.S.', 'Genres': 'Country [2] alt-country [3] honky-tonk [4] red dirt [5]', 'Occupation(s)': 'Singer-songwriter', 'Instrument(s)': 'Vocals guitar harmonica', 'Years active': '2017–present', 'Labels': 'Warner Belting Broncos', 'Website': 'www .zachbryan .com', 'Allegiance': 'United States', 'Service/branch': 'United States Navy', 'Years\xa0of service': '2013–2021', 'Rank': 'Petty Officer Second Class'}
# Sidebar found. Extracting information...
# {'Born': 'Zain Javadd Malik ( 1993-01-12 ) 12 January 1993 (age\xa030) Bradford, West Yorkshire , England', 'Occupation': 'Singer', 'Years\xa0active': '2010–present', 'Works': 'Discography', 'Partner': 'Gigi Hadid (2015–2021)', 'Children': '1', 'Awards': 'Full list', 'Genres': 'Pop [1] R&B [2]', 'Labels': 'Syco Columbia RCA Mercury', 'Formerly of': 'One Direction', 'Website': 'inzayn .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'Anton Zaslavski', 'Born': '( 1989-09-02 ) 2 September 1989 (age\xa034) Saratov , Russian SFSR , Soviet Union (present-day Russia)', 'Origin': 'Kaiserslautern , Germany', 'Genres': 'EDM', 'Occupation(s)': 'DJ record producer songwriter', 'Years active': '2002–present', 'Labels': "Interscope Owsla Spinnin' Dim Mak", 'Website': 'zedd .net'}
# Sidebar found. Extracting information...
# {'Birth name': 'Benjamin Joseph Levin', 'Also known as': 'Ebba Ebba', 'Born': '( 1988-03-08 ) March 8, 1988 (age\xa035) Reston, Virginia , U.S.', 'Genres': 'Pop [1]', 'Occupation(s)': 'Record producer disc jockey songwriter record executive', 'Years active': '2007–present', 'Labels': 'Mad Love Interscope Friends Keep Secrets', 'Formerly of': 'Bangers & Cash BenZel', 'Website': 'benny-blanco .com'}
# Disambiguation page detected. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/Black_Bear_(band)
# Sidebar found. Extracting information...
# {'Origin': 'Canada', 'Genres': 'Northern contemporary', 'Years active': '2000–present', 'Labels': 'Tribal Spirit Music', 'Website': 'blackbearsingers .com'}
# Sidebar found. Extracting information...
# {'Origin': 'New York City, U.S.', 'Genres': 'Baroque pop [1] alternative rock pop rock [2]', 'Years active': '2008–2015 (on hiatus)', 'Labels': 'Nettwerk Fueled by Ramen', 'Members': 'Nate Ruess Jack Antonoff Andrew Dost', 'Website': 'ournameisfun .com'}
# Disambiguation page detected. Finding relevant link...
# Found relevant link: https://en.wikipedia.org/wiki/Gnash_(musician)
# Sidebar found. Extracting information...
# {'Birth name': 'Garrett Charles Nash', 'Born': '( 1993-06-16 ) June 16, 1993 (age\xa030) Los Angeles, California, U.S.', 'Genres': 'Pop hip hop alternative R&B indie folk', 'Occupation(s)': 'Musician singer songwriter DJ record producer', 'Years active': '2015–present', 'Labels': 'Atlantic', 'Website': 'gnash .us'}
# Sidebar found. Extracting information...
# {'Origin': 'Columbus, Ohio , U.S.', 'Genres': 'Alternative rock alternative hip hop electropop rap rock indie pop pop rock emo [1] (early)', 'Discography': 'Twenty One Pilots discography', 'Years active': '2009–present', 'Labels': 'Fueled by Ramen Elektra Atlantic', 'Members': 'Tyler Joseph Josh Dun', 'Past members': 'Chris Salih Nick Thomas', 'Website': 'twentyonepilots .com'}
# Sidebar found. Extracting information...
# {'Birth name': 'William James Adams Jr.', 'Also known as': 'Will 1X illwilly Willonex Zuper Blahq', 'Born': '( 1975-03-15 ) March 15, 1975 (age\xa048) Los Angeles , California , U.S.', 'Genres': 'Hip hop pop rap pop R&B', 'Occupation(s)': 'Rapper singer songwriter record producer actor', 'Instruments': 'Vocals keyboards piano bass drums', 'Years active': '1988–present', 'Labels': 'E1 Interscope Beat Generation will.i.am Barely Breaking Even Atlantic Ruthless Epic', 'Member of': 'Black Eyed Peas', 'Formerly of': 'Atban Klann Jawbreakers', 'Relatives': 'Lynn Cain (uncle)', 'Website': 'will .i .am'}

# %%
print(len(urls))
print(len(names))
print(len(scraped_sidebars))
print(len(sidebars_content))
# Out:
# 505
# 505
# 505
# 505

# %%
data = {'URL': urls, 'Name': names, 'Scraped_Sidebar': scraped_sidebars,
        'Sidebar_Content': sidebars_content}
sidebars_df = pd.DataFrame(data)

sidebars_df
# Out:
#                                                    URL                 Name  \
# 0               https://en.wikipedia.org/wiki/2_Chainz             2 Chainz
# 1              https://en.wikipedia.org/wiki/21_Savage            21 Savage
# 2               https://en.wikipedia.org/wiki/24kGoldn             24kGoldn
# 3                  https://en.wikipedia.org/wiki/3OH!3                3OH!3
# 4    https://en.wikipedia.org/wiki/5_Seconds_Of_Summer  5 Seconds Of Summer
# ..                                                 ...                  ...
# 500            https://en.wikipedia.org/wiki/Blackbear            blackbear
# 501                 https://en.wikipedia.org/wiki/Fun.                 fun.
# 502                https://en.wikipedia.org/wiki/Gnash                gnash
# 503    https://en.wikipedia.org/wiki/Twenty_one_pilots    twenty one pilots
# 504            https://en.wikipedia.org/wiki/Will.i.am            will.i.am
#
#                                        Scraped_Sidebar  \
# 0    {'Born': 'Tauheed K. Epps ( 1977-09-12 ) Septe...
# 1    {'Birth name': 'Shéyaa Bin Abraham-Joseph', 'B...
# 2    {'Birth name': 'Golden Landis Von Jones', 'Als...
# 3    {'Origin': 'Boulder, Colorado , U.S.', 'Genres...
# 4    {'Also known as': '5SOS', 'Origin': 'Sydney , ...
# ..                                                 ...
# 500  {'Origin': 'Canada', 'Genres': 'Northern conte...
# 501  {'Origin': 'New York City, U.S.', 'Genres': 'B...
# 502  {'Birth name': 'Garrett Charles Nash', 'Born':...
# 503  {'Origin': 'Columbus, Ohio , U.S.', 'Genres': ...
# 504  {'Birth name': 'William James Adams Jr.', 'Als...
#
#                                        Sidebar_Content
# 0    [Tauheed K. Epps ( 1977-09-12 ) September 12, ...
# 1    [Shéyaa Bin Abraham-Joseph ( 1992-10-22 ) Octo...
# 2    [Golden Landis Von Jones Goldn El Dorado ( 200...
# 3    [Boulder, Colorado , U.S. Electropop synth-pop...
# 4    [5SOS Sydney , New South Wales , Australia Pop...
# ..                                                 ...
# 500  [Canada Northern contemporary 2000–present Tri...
# 501  [New York City, U.S. Baroque pop [1] alternati...
# 502  [Garrett Charles Nash ( 1993-06-16 ) June 16, ...
# 503  [Columbus, Ohio , U.S. Alternative rock altern...
# 504  [William James Adams Jr. Will 1X illwilly Will...
#
# [505 rows x 4 columns]

# %%
sidebars_df.to_pickle('raw_data_from_preproc.pkl')

# %% [markdown]
# # Query Data

# %%
query_url = 'https://en.wikipedia.org/wiki/Laufey_(singer)'
query_sidebar = scrape_wikipedia_sidebar(query_url)
query_data = [[query_url, query_sidebar,
              ' '.join(list(query_sidebar.values()))]]
query_df = pd.DataFrame(query_data, index=['Laufey'],
                        columns=['URL', 'Scraped_Sidebar', 'Sidebar_Content'])
query_df
# Out:
# Sidebar found. Extracting information...
#                                                   URL  \
# Laufey  https://en.wikipedia.org/wiki/Laufey_(singer)
#
#                                           Scraped_Sidebar  \
# Laufey  {'Birth name': 'Laufey Lín Bīng Jónsdóttir / 林...
#
#                                           Sidebar_Content
# Laufey  Laufey Lín Bīng Jónsdóttir / 林冰 [1] ( 1999-04-...

# %%
query_df.to_pickle('query_df.pkl')
